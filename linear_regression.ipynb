# %%
import pandas as pd

# %%
df = pd.read_csv("./data/melb_data.csv")
df.head()
# Out:
#        Suburb           Address  Rooms Type      Price Method SellerG  \
# 0  Abbotsford      85 Turner St      2    h  1480000.0      S  Biggin
# 1  Abbotsford   25 Bloomburg St      2    h  1035000.0      S  Biggin
# 2  Abbotsford      5 Charles St      3    h  1465000.0     SP  Biggin
# 3  Abbotsford  40 Federation La      3    h   850000.0     PI  Biggin
# 4  Abbotsford       55a Park St      4    h  1600000.0     VB  Nelson
#
#         Date  Distance  Postcode  ...  Bathroom  Car  Landsize  BuildingArea  \
# 0  3/12/2016       2.5    3067.0  ...       1.0  1.0     202.0           NaN
# 1  4/02/2016       2.5    3067.0  ...       1.0  0.0     156.0          79.0
# 2  4/03/2017       2.5    3067.0  ...       2.0  0.0     134.0         150.0
# 3  4/03/2017       2.5    3067.0  ...       2.0  1.0      94.0           NaN
# 4  4/06/2016       2.5    3067.0  ...       1.0  2.0     120.0         142.0
#
#    YearBuilt  CouncilArea Lattitude  Longtitude             Regionname  \
# ...

# %%
df = pd.read_csv("./data/melb_data.csv")

# Retirar colunas com alta cardinalidade
df = df.drop(["Suburb", "Address", "SellerG", "Date"], axis=1)

# Muitos valores Nulos
df = df.drop(["BuildingArea", "YearBuilt", "CouncilArea"], axis=1)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13580 entries, 0 to 13579
# Data columns (total 14 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Rooms          13580 non-null  int64
#  1   Type           13580 non-null  object
#  2   Price          13580 non-null  float64
#  3   Method         13580 non-null  object
#  4   Distance       13580 non-null  float64
#  5   Postcode       13580 non-null  float64
#  6   Bedroom2       13580 non-null  float64
#  7   Bathroom       13580 non-null  float64
#  8   Car            13518 non-null  float64
#  9   Landsize       13580 non-null  float64
#  10  Lattitude      13580 non-null  float64
#  11  Longtitude     13580 non-null  float64
#  12  Regionname     13580 non-null  object
#  13  Propertycount  13580 non-null  float64
# dtypes: float64(10), int64(1), object(3)
# memory usage: 1.5+ MB

# %%
df.corr()
# Out:
# /var/folders/hx/471dtkq13315bmvjls838b4h0000gn/T/ipykernel_3557/1134722465.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.corr()
#                   Rooms     Price  Distance  Postcode  Bedroom2  Bathroom  \
# Rooms          1.000000  0.496634  0.294203  0.055303  0.944190  0.592934
# Price          0.496634  1.000000 -0.162522  0.107867  0.475951  0.467038
# Distance       0.294203 -0.162522  1.000000  0.431514  0.295927  0.127155
# Postcode       0.055303  0.107867  0.431514  1.000000  0.060584  0.113664
# Bedroom2       0.944190  0.475951  0.295927  0.060584  1.000000  0.584685
# Bathroom       0.592934  0.467038  0.127155  0.113664  0.584685  1.000000
# Car            0.408483  0.238979  0.262994  0.050289  0.405325  0.322246
# ...

# %%
# Escolhendo colunas com relação mais alta com price
base1 = df[["Price","Rooms","Bedroom2","Bathroom","Car"]]

# Tratando nulos

base1 = base1.dropna(axis=0)

base1
# Out:
#            Price  Rooms  Bedroom2  Bathroom  Car
# 0      1480000.0      2       2.0       1.0  1.0
# 1      1035000.0      2       2.0       1.0  0.0
# 2      1465000.0      3       3.0       2.0  0.0
# 3       850000.0      3       3.0       2.0  1.0
# 4      1600000.0      4       3.0       1.0  2.0
# ...          ...    ...       ...       ...  ...
# 13575  1245000.0      4       4.0       2.0  2.0
# 13576  1031000.0      3       3.0       2.0  2.0
# 13577  1170000.0      3       3.0       2.0  4.0
# 13578  2500000.0      4       4.0       1.0  5.0
# 13579  1285000.0      4       4.0       1.0  1.0
#
# [13518 rows x 5 columns]

# %% [markdown]
# ###  Criando o Modelo Machine Learning

# %%
Y = base1["Price"]
X = base1[["Rooms","Bedroom2","Bathroom", "Car"]]

# %%
from sklearn.model_selection import train_test_split

x_treino, x_teste, y_treino, y_teste = train_test_split(X,Y)

# %%
# Importando o modelo - Linear Regression
from sklearn.linear_model import LinearRegression

# Instanciando o modelo
reg = LinearRegression()

# Realizando o fit do modelo - treino
reg = reg.fit(x_treino, y_treino)

# Usando o modelo para prever os dados em x_teste

y_regressao = reg.predict(x_teste)

# %%
import plotly.express as px

fig = px.scatter(x=y_teste, y=y_regressao)
fig.show()

# %%
# Avaliando o erro quadrático médio
from sklearn.metrics import mean_squared_error

erro_quadratico_regressao = mean_squared_error(y_teste, y_regressao)
print(erro_quadratico_regressao)
# Out:
# 315840028721.05225

# %%
# Avaliando o R quadrado

from sklearn.metrics import r2_score

R_quadrado = r2_score(y_teste, y_regressao)
print(R_quadrado)
# Out:
# 0.25980816298830633

# %% [markdown]
# ### Arvore de Decisão

# %%
# Importando o modelo
from sklearn.tree import DecisionTreeRegressor


# Instanciando o modelo
reg2 = DecisionTreeRegressor()

# Realizando o fit do modelo - treino
reg2 = reg2.fit(x_treino, y_treino)

# Usando o modelo para prever os dados em x_teste

y_regressao2 = reg2.predict(x_teste)

# %%
fig = px.scatter(x=y_teste, y=y_regressao2)
fig.show()

# %%
# Avaliando o erro quadrático médio
from sklearn.metrics import mean_squared_error

erro_quadratico_regressao2 = mean_squared_error(y_teste, y_regressao2)
print(erro_quadratico_regressao2)
# Out:
# 316396324167.93317

# %%
# Avaliando o R quadrado

from sklearn.metrics import r2_score

R_quadrado = r2_score(y_teste, y_regressao2)
print(R_quadrado)
# Out:
# 0.2585044480968931
